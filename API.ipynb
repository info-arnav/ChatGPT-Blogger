# %%
import openai
openai.api_key = "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"

# %%
dictionary = {}
array = [
 "10 Mistakes to Avoid When Starting Your Blog",
 "The Ultimate Guide to Blogging for Beginners",
 "Expert Blogging Tips from Top Influencers",
 "How to Build a Successful Blog from Scratch",
 "The Top Blogging Trends to Watch Out for in 2023",
 "The Future of Blogging: What You Need to Know",
 "10 SEO Strategies to Boost Your Blog Traffic",
 "The Power of Social Media for Bloggers",
 "10 Essential Tools for Every Blogger",
 "How to Monetize Your Blog: Tips and Tricks",
 "5 Secrets to Writing Engaging Blog Posts",
 "10 Creative Ideas for Your Next Blog Post",
 "How to Stand Out in a Crowded Blogging Niche",
 "10 Ways to Increase Your Blog's Visibility",
 "The Pros and Cons of Guest Blogging",
 "10 Common Blogging Mistakes and How to Fix Them",
 "The Role of Blogging in Today's Digital Marketing Landscape",
 "How to Create a Successful Blogging Strategy",
 "10 Tips for Writing Killer Headlines That Grab Attention",
 "The Dos and Don'ts of Blog Design",
 "10 Ways to Make Your Blog Posts More Shareable",
 "The Benefits of Blogging for Personal Branding",
 "10 Blogging Hacks to Save You Time and Effort",
 "How to Find Your Blogging Voice",
 "10 Ways to Overcome Writer's Block",
 "The Importance of Consistency in Blogging",
 "10 Ways to Use Video in Your Blogging Strategy",
 "How to Build a Community Around Your Blog",
 "10 Steps to Take Before Launching Your Blog",
 "The Ethics of Blogging: What Every Blogger Should Know",
 "10 Tools for Managing Your Blogging Workflow",
 "The Art of Storytelling in Blogging",
 "10 Reasons Why Your Blog Isn't Getting Traffic",
 "How to Leverage Email Marketing for Your Blog",
 "10 Tips for Writing SEO-Friendly Blog Posts",
 "The Psychology of Blogging: How to Connect with Your Audience",
 "10 Best Practices for Successful Blogging",
 "How to Promote Your Blog on Social Media",
 "10 Ways to Build Trust with Your Blog Audience",
 "The Benefits of Collaborating with Other Bloggers",
 "10 Blogging Mistakes That Could Hurt Your Brand",
 "How to Optimize Your Blog for Mobile Devices",
 "10 Reasons Why Blogging is Good for Your Mental Health",
 "The Power of Visuals in Blogging",
 "10 Tips for Creating Compelling Infographics",
 "The Importance of Building Your Email List",
 "10 Ways to Improve Your Blog's User Experience",
 "The Ethics of Affiliate Marketing for Bloggers",
 "10 Tips for Writing Long-Form Content That Keeps Readers Engaged",
 "The Pros and Cons of Paid Traffic for Your Blog",
 "10 Ways to Repurpose Your Blog Content",
 "How to Find Your Blogging Niche",
 "10 Steps for Creating a Successful Blogging Workflow",
 "The Benefits of Outsourcing Your Blogging Tasks",
 "10 Ways to Measure Your Blog's Success",
 "How to Create a Content Calendar for Your Blog",
 "10 Ways to Build Your Authority as a Blogger",
 "The Dos and Don'ts of Blog Commenting",
 "10 Creative Ways to Monetize Your Blog",
 "How to Use Analytics to Improve Your Blog Performance",
 "10 Tips for Writing Compelling Calls to Action",
 "The Future of Blog Monetization: What to Expect",
 "10 Reasons Why Your Blog Needs a Podcast",
 "How to Create a Brand Style Guide for Your Blog",
 "10 Ways to Boost Your Blog's Engagement",
 "The Role of Storytelling in Branding Your Blog",
 "10 Tips for Writing Product Reviews"
]

# %%
        for x in array:
            if x not in dictionary.keys():
                title = x
                data = openai.ChatCompletion.create(
                  model="gpt-3.5-turbo",
                  messages=[
                        {"role": "user", "content": "Write a blog for a blogging website being really descriptive as to compete with the content on wikipdeia in word count greater than 1500 with the title '"+title+"', enclode the content in a htl article tag with appropriate break line tags. dont add title html or body tags. add bold and underline where necessary. and focus on any kewords you find appropriate for the topic. just give me the article without and other introductory sentence" }
                    ]
                )
                dictionary[x] = data.choices[0].message.content
            print(dictionary[x])
# Out:
# <h1>10 Mistakes to Avoid When Starting Your Blog</h1>
#
# Starting a blog can be a daunting task. Whether you are doing it for fun, to showcase your writing skills, or as part of a business strategy, you need to make sure you avoid the common mistakes that many beginners make. In this article, we will go over 10 mistakes to avoid when starting your blog.
#
# <h2>Mistake #1: Not Having a Plan</h2>
#
# One of the biggest mistakes you can make is to start a blog without a plan. You need to know what your blog will be about, who your target audience is, and what your goals are. You should also have a content strategy and a publishing schedule. Without a plan, you risk getting overwhelmed and losing motivation.
#
# <h2>Mistake #2: Choosing the Wrong Blogging Platform</h2>
#
# ...
